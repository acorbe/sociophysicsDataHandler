# %%
# %load_ext autoreload
# %autoreload 2

from sociophysicsDataHandler import SociophysicsDataHandler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dh = SociophysicsDataHandler()

dh.fetch_background_image_from_path('asdz/background_images/asdz-platform2.1-stairs.bmp')
dh.bg
# Out:
# trying to fetch: /ProRail_USE_LL_data/asdz/background_images/asdz-platform2.1-stairs.bmp
# background fetched. Accessible as <this-object>.bg
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=978x653 at 0x7F0500646978>

# %%
dh.fetch_background_image_from_path('asdz/background_images/asdz-platform2.2-esc.bmp')
dh.bg
# Out:
# trying to fetch: /ProRail_USE_LL_data/asdz/background_images/asdz-platform2.2-esc.bmp
# background fetched. Accessible as <this-object>.bg
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=978x690 at 0x7F05000AC208>
